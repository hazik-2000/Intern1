# %% [markdown]
# # importing all required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %% [markdown]
# ***read csv file**

# %%
df=pd.read_csv("weatherHistory.csv")
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# ***getting necessary in formation of file**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
column,rows=df.shape

# %%
column
# Out:
# 96453

# %%
rows
# Out:
# 11

# %% [markdown]
# # checking if any null values

# %%
df.isnull()
# Out:
#        Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0               False    False        False            False
# 1               False    False        False            False
# 2               False    False        False            False
# 3               False    False        False            False
# 4               False    False        False            False
# ...               ...      ...          ...              ...
# 96448           False    False        False            False
# 96449           False    False        False            False
# 96450           False    False        False            False
# 96451           False    False        False            False
# 96452           False    False        False            False
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                         False     False              False
# 1                         False     False              False
# ...

# %% [markdown]
# # droping the non required coulmns axis=1

# %%
df=df.drop(["Summary","Precip Type","Wind Speed (km/h)","Wind Bearing (degrees)","Visibility (km)",'Pressure (millibars)',"Daily Summary"],axis=1)

# %%
df
# Out:
#                       Formatted Date  Temperature (C)  \
# 0      2006-04-01 00:00:00.000 +0200         9.472222
# 1      2006-04-01 01:00:00.000 +0200         9.355556
# 2      2006-04-01 02:00:00.000 +0200         9.377778
# 3      2006-04-01 03:00:00.000 +0200         8.288889
# 4      2006-04-01 04:00:00.000 +0200         8.755556
# ...                              ...              ...
# 96448  2016-09-09 19:00:00.000 +0200        26.016667
# 96449  2016-09-09 20:00:00.000 +0200        24.583333
# 96450  2016-09-09 21:00:00.000 +0200        22.038889
# 96451  2016-09-09 22:00:00.000 +0200        21.522222
# 96452  2016-09-09 23:00:00.000 +0200        20.438889
#
#        Apparent Temperature (C)  Humidity
# 0                      7.388889      0.89
# 1                      7.227778      0.86
# 2                      9.377778      0.89
# 3                      5.944444      0.83
# 4                      6.977778      0.83
# ...                         ...       ...
# ...

# %% [markdown]
# # changing type of formatted date from str to Timestamp

# %%
df["Formatted Date"]=pd.to_datetime(df['Formatted Date'],utc=True)

# %%
type(df['Formatted Date'])
# Out:
# pandas.core.series.Series

# %%
type(df['Formatted Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# # setting the index

# %%
df.set_index("Formatted Date",inplace=True)

# %%
df.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-03-31 22:00:00+00:00         9.472222                  7.388889      0.89
# 2006-03-31 23:00:00+00:00         9.355556                  7.227778      0.86
# 2006-04-01 00:00:00+00:00         9.377778                  9.377778      0.89
# 2006-04-01 01:00:00+00:00         8.288889                  5.944444      0.83
# 2006-04-01 02:00:00+00:00         8.755556                  6.977778      0.83

# %% [markdown]
# # Resampling data as per requirement

# %%
df1=df[['Apparent Temperature (C)',"Humidity"]].resample('MS').mean()

# %%
df1
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %%
df1.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %% [markdown]
# # PLOTTING FIRST PLOT FOR ANALYSIS OF TEMP VS HUMIDITY OVER A PERIOD OF YEAR

# %%
plt.figure(figsize=(16,9))
plt.plot(df1['Humidity'],label='humidity')
plt.plot(df1['Apparent Temperature (C)'],label='Apparent temperature')
plt.xlabel("Years",fontsize=20)

plt.legend(shadow=True,ncol=2,labelspacing=3)
plt.title('Apparent Temperature VS Humidity 10years data',fontsize=20,bbox={'color':'silver'},pad=15)
plt.grid()
plt.show()

# %% [markdown]
# # PLOTTING THE GRAPH FOR SPECIFIC MONTHS

# %%
df3=df1.reset_index()

# %%
df4=df3[df3['Formatted Date'].dt.month==6]

# %%
df4.set_index('Formatted Date',inplace=True)

# %%
df4
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-06-01 00:00:00+00:00                 19.535965  0.747125
# 2007-06-01 00:00:00+00:00                 21.883102  0.616486
# 2008-06-01 00:00:00+00:00                 21.513750  0.679861
# 2009-06-01 00:00:00+00:00                 19.526790  0.675944
# 2010-06-01 00:00:00+00:00                 20.340571  0.778347
# 2011-06-01 00:00:00+00:00                 21.157114  0.677611
# 2012-06-01 00:00:00+00:00                 22.157130  0.622306
# 2013-06-01 00:00:00+00:00                 20.345664  0.761847
# 2014-06-01 00:00:00+00:00                 19.874306  0.602403
# 2015-06-01 00:00:00+00:00                 20.511782  0.655208
# 2016-06-01 00:00:00+00:00                 21.463387  0.733458

# %%
df5=df3[df3['Formatted Date'].dt.month==12]

# %%
df5.set_index("Formatted Date",inplace=True)

# %%
df5
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-12-01 00:00:00+00:00                  0.107310  0.905376
# 2007-12-01 00:00:00+00:00                 -2.964897  0.856250
# 2008-12-01 00:00:00+00:00                  0.327389  0.828226
# 2009-12-01 00:00:00+00:00                 -0.169086  0.844637
# 2010-12-01 00:00:00+00:00                 -3.485947  0.913602
# 2011-12-01 00:00:00+00:00                  0.618093  0.866223
# 2012-12-01 00:00:00+00:00                 -3.672909  0.886801
# 2013-12-01 00:00:00+00:00                 -0.690054  0.823965
# 2014-12-01 00:00:00+00:00                  0.556586  0.835927
# 2015-12-01 00:00:00+00:00                  0.828644  0.925390
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981

# %%
df6=df3[df3['Formatted Date'].dt.month==1]
df6.set_index("Formatted Date",inplace=True)
df6
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2007-01-01 00:00:00+00:00                  2.387015  0.813495
# 2008-01-01 00:00:00+00:00                 -2.069907  0.819476
# 2009-01-01 00:00:00+00:00                 -3.669937  0.867621
# 2010-01-01 00:00:00+00:00                 -4.329062  0.875914
# 2011-01-01 00:00:00+00:00                 -2.186813  0.922030
# 2012-01-01 00:00:00+00:00                 -1.965211  0.797581
# 2013-01-01 00:00:00+00:00                 -1.768578  0.883105
# 2014-01-01 00:00:00+00:00                  0.234536  0.846169
# 2015-01-01 00:00:00+00:00                 -0.770124  0.831519
# 2016-01-01 00:00:00+00:00                 -3.014576  0.866156

# %%
df7=df3[df3['Formatted Date'].dt.month==4]
df7.set_index("Formatted Date",inplace=True)
df7
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# 2007-04-01 00:00:00+00:00                 11.894421  0.536361
# 2008-04-01 00:00:00+00:00                 11.183688  0.693194
# 2009-04-01 00:00:00+00:00                 14.267076  0.567847
# 2010-04-01 00:00:00+00:00                 11.639406  0.706875
# 2011-04-01 00:00:00+00:00                 12.978997  0.591625
# 2012-04-01 00:00:00+00:00                 11.782770  0.650222
# 2013-04-01 00:00:00+00:00                 12.045563  0.677667
# 2014-04-01 00:00:00+00:00                 12.486181  0.691403
# 2015-04-01 00:00:00+00:00                 10.632801  0.547764
# 2016-04-01 00:00:00+00:00                 12.731427  0.659972

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.plot(df4['Apparent Temperature (C)'],label='Apparent Temperature',marker='D')
plt.plot(df4['Humidity'],label='Humidity',marker='o')
plt.legend()
plt.xlabel("June")
plt.grid()
plt.subplot(2,2,2)
plt.plot(df5['Apparent Temperature (C)'],label='Apparent Temperature',marker='D')
plt.plot(df5['Humidity'],label='Humidity',marker='o')
plt.xlabel("December")
plt.legend(loc=(0.63,0))
plt.grid()
plt.subplot(2,2,3)
plt.plot(df6['Apparent Temperature (C)'],label='Apparent Temperature',marker='D')
plt.plot(df6['Humidity'],label='Humidity',marker='o')
plt.xlabel("January")
plt.legend()
plt.grid()
plt.subplot(2,2,4)
plt.plot(df7['Apparent Temperature (C)'],label='Apparent Temperature',marker='D')
plt.plot(df7['Humidity'],label='Humidity',marker='o')
plt.xlabel("April")
plt.legend()
plt.grid()
plt.suptitle("ANALYSIS FOR PARTICULAR MONTH",bbox={'facecolor':'silver'},fontsize=17)
plt.savefig("watherhistory",dpi=100)
plt.show()
